// %% [markdown]
// # Setup

// %%
import $ivy.`com.lihaoyi::os-lib:0.11.5`
// Out:
// import $ivy.$

// %% [markdown]
// # Ammonite-REPL

// %%
// for side effect
import $file.snippets.`2.12`.MyScript
// Out:
// Compiling d:\workspace\github\learning-scala\tools\snippets\2.12\MyScript.sc
// Hello World!!
// x is 123
// import $file.$

// %%
// imports functions, etc
import $file.snippets.`2.12`.MyScript, MyScript._

hello()
exec("scala.bat", "-version")
// Out:
// Hello Scala!
// import imports functions, etc
// import $file.$                       , MyScript._

// %%
// jars, NOT folders
// import $cp.`../Scala/snippets/*`

// how to import no package jars???
// Out:
// import $cp.$

// %% [markdown]
// # Scala Scripts

// %%
val res = os.proc("amm.bat", "snippets/2.12/MyScript.sc").call()
println((res.exitCode, res.out.trim(), res.err.trim()))
// Out:
// cmd6.sc:121: imported `MyScript` is permanently hidden by definition of value MyScript in class cmd6
//   instance => MyScript
//   ^
// (0,Hello World!!
// x is 123,)
// res: os.CommandResult = CommandResult(
//   ArrayBuffer("amm.bat", "snippets/2.12/MyScript.sc"),
//   0,
//   Vector(
//     Left(
//       Hello World!!
//
//     ),
//     Left(
//       x is 123
//
//     )
//   )
// )
