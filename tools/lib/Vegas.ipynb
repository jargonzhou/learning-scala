// %% [markdown]
// # Vegas
// * https://github.com/vegas-viz/Vegas

// %% [markdown]
// # Setup

// %%
// https://mvnrepository.com/artifact/org.vegas-viz/vegas
// 0.3.11, 2.11,  Jul 25, 2017
import $ivy.`org.vegas-viz::vegas:0.3.11`
