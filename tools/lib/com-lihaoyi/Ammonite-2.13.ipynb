// %% [markdown]
// # Setup

// %%
import $ivy.`com.lihaoyi::os-lib:0.11.5`
// Out:
// import $ivy.$

// %% [markdown]
// # Ammonite-REPL

// %%
// imports functions, etc
import $file.snippets.`2.13`.MyScript, MyScript._

hello()
// Out:
// Hello World!!
// x is 123
// Hello Scala!
// import imports functions, etc
// import $file.$                       , MyScript._

// %%
val res = os.proc("scala.bat", "-version").call()
println((res.exitCode, res.out.trim(), res.err.trim()))
// Out:
// cmd3.sc:120: imported `MyScript` is permanently hidden by definition of value MyScript in class cmd3
//   instance => MyScript
//   ^
// (0,,)
// res: os.CommandResult = CommandResult(
//   command = ArraySeq("scala.bat", "-version"),
//   exitCode = 0,
//   chunks = Vector()
// )

// %%
exec("scala.bat", "snippets/2.13/hello.scala")
// Out:
// cmd4.sc:121: imported `MyScript` is permanently hidden by definition of value MyScript in class cmd4
//   instance => MyScript
//   ^
// Hello, Scala!

// %%
// jars, NOT folders
// import $cp.`../Scala/snippets/*`

// how to import no package jars???

// %% [markdown]
// # Scala Scripts

// %%
val res = os.proc("amm.bat", "snippets/2.13/MyScript.sc").call()
println((res.exitCode, res.out.trim(), res.err.trim()))
// Out:
// cmd5.sc:122: imported `MyScript` is permanently hidden by definition of value MyScript in class cmd5
//   instance => MyScript
//   ^
// (0,Hello World!!
// x is 123,)
// res: os.CommandResult = CommandResult(
//   command = ArraySeq("amm.bat", "snippets/2.13/MyScript.sc"),
//   exitCode = 0,
//   chunks = Vector(
//     Left(
//       value = Hello World!!
//
//     ),
//     Left(
//       value = x is 123
//
//     )
//   )
// )
