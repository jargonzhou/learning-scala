// %% [markdown]
// # Setup

// %%
import $ivy.`com.lihaoyi::os-lib:0.11.5`
// Out:
// import $ivy.$

// %% [markdown]
// # Ammonite-REPL

// %%
// imports functions, etc
import $file.snippets.`3`.MyScript, MyScript._

hello()
// Out:
// Compiling d:\workspace\github\learning-scala\tools\snippets\3\MyScript.sc
// Hello World!!
// x is 123
// Hello Scala!
// import $file.$                    , MyScript._

// %%
// val res = os.proc("scala.bat", "-version").call()
// println((res.exitCode, res.out.trim(), res.err.trim()))
exec("scala.bat", "-version")
// Out:
// Scala code runner version: 1.9.0
// Scala version (default): 3.7.3

// %%
exec("scala.bat", "snippets/3/hello.scala")
// Out:
// Hello, Scala!

// %%
// jars, NOT folders
// import $cp.`../Scala/snippets/*`

// how to import no package jars???

// %% [markdown]
// # Scala Scripts

// %%
val res = os.proc("amm303.bat", "snippets/3/MyScript.sc").call()
println((res.exitCode, res.out.trim(), res.err.trim()))
// Out:
// (0,Hello World!!
// x is 123,)
// res: CommandResult = CommandResult(
//   command = ArraySeq("amm303.bat", "snippets/3/MyScript.sc"),
//   exitCode = 0,
//   chunks = Vector(
//     Left(
//       value = Hello World!!
// x is 123
//
//     )
//   )
// )
