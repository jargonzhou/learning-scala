// %% [markdown]
// # reftree
// * https://github.com/stanch/reftree
//
// > Automatically generated diagrams and animations for Scala data structures

// %%
import $ivy.`io.github.stanch::reftree:1.5.0`

// import almond.display._

{{
  import reftree.render._, reftree.diagram._
  import reftree.contrib.SimplifiedInstances.string
  val renderer = Renderer(renderingOptions = RenderingOptions(density = 75))
    
  case class Person(name: String, age: Int)
  val people = List(
    Person("Alice", 29),
    Person("Bob", 23),
    Person("Charlie", 34)
  )

  try {
    renderer.render("example", Diagram.sourceCodeCaption(people))
  } catch {
    case ex: Exception => println(ex)
  }
}}

Image.fromFile("example.png")
// Out:
// reftree.render.DotRenderer$RenderingException:
// (dot.exe:8268): Pango-WARNING **: couldn't load font "Source Code Pro Italic Not-Rotated 14", falling back to "Sans Italic Not-Rotated 14", expect ugly output.
//
// (dot.exe:8268): Pango-WARNING **: couldn't load font "Source Code Pro Not-Rotated 14", falling back to "Sans Not-Rotated 14", expect ugly output.
// import $ivy.$
