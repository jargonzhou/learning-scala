// %% [markdown]
// # Setup

// %%
import $ivy.`org.scalaz::scalaz-core:7.3.8`, scalaz._, Scalaz._

(Option(1) |@| Option(2))(_ + _)
// Out:
// import $ivy.$                              , scalaz._, Scalaz._
//
//
// res1_1: Option[Int] = Some(3)
